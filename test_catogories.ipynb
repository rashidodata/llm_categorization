# %%
# Step 1: Import the necessary functions
from llm_categorize import test_single_json_file, process_all_facebook_zip_files
import pandas as pd
# Step 2: Define the path to your local ad_preferences.json
api_key = ''
base_folder = '/Users/rashido/Desktop/mexico'
# Step 3: Run classification
df_result = process_all_facebook_zip_files(zip_folder=base_folder, api_key=api_key)

# Step 4: View the result
df_result.head()
# Out:
# INFO:llm_categorize:Scanning ZIP files in: /Users/rashido/Desktop/mexico
# INFO:llm_categorize:Processing ZIP: /Users/rashido/Desktop/mexico/5d3ce65a33b894000125909b_facebook-anadominguez750331-04_02_2025-2a5HKpeD.zip
# INFO:llm_categorize:Processing ZIP: /Users/rashido/Desktop/mexico/5e18cc8f30626119a3998c31_facebook-100086646456457-30_01_2025-5AlDfXg6.zip
# INFO:llm_categorize:Classifying batch of 3 interests
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# INFO:llm_categorize:Processing ZIP: /Users/rashido/Desktop/mexico/610c014be99f3bf9eecb2a91_facebook-robingraves71-04_02_2025-df8tgNFW.zip
# INFO:llm_categorize:Processing ZIP: /Users/rashido/Desktop/mexico/5f355c1eb1d3e10e9c4eb6a0_facebook-Paaattie-2025-02-02-tAxY7lq8.zip
# ...
